# %%
# !poetry run python -m graphrag.index --init --root ./ragtest
# Out:
# Initializing project at ./ragtest
# ⠋ GraphRAG Indexer

# %%
# !poetry run python -m graphrag.prompt_tune --root ./ragtest --config settings.yaml --language Japanese

# %%
# !poetry run python -m graphrag.index --root ./ragtest

# %%
import pandas as pd

# %%
df = pd.read_parquet("ragtest/output/20240916-111521/artifacts/create_final_text_units.parquet")
df = pd.read_parquet("ragtest/output/20240916-111521/artifacts/create_final_entities.parquet")
df = pd.read_parquet("ragtest/output/20240916-111521/artifacts/create_final_relationships.parquet")
df
# Out:
#       source    target  weight  \
# 0         巨人  ウォール・マリア    18.0
# 1         巨人  ウォール・ローゼ    26.0
# 2         巨人  ウォール・シーナ     9.0
# 3         巨人        人類    11.0
# 4         巨人     超大型巨人    19.0
# ...      ...       ...     ...
# 1087  ミュラー長官      マーレ兵     9.0
# 1088  ミュラー長官    レオンハート     8.0
# 1089  ミュラー長官        停戦     8.0
# 1090  ミュラー長官      マーレ人     8.0
# 1091    地ならし      光る生物     1.0
#
#                                             description  \
# 0     巨人はウォール・マリア内で確認され、脅威となっている存在である。彼らは人類を滅亡の淵に立たせ...
# 1     巨人とウォール・ローゼに関する説明は、巨人の侵攻が地域住民に大きな影響を与えたことを示してい...
# 2     巨人はウォール・シーナの壁の中から発見され、人類を滅亡の淵に立たせる存在である。彼らの出現は...
# 3     巨人と人類に関する記述によれば、巨人の出現によって人類の大半が死滅し、彼らは人類を滅亡の淵に...
# 4     超大型巨人は、壁を破って巨人の群れを侵入させた存在であり、他の巨人の侵入経路を開けた。彼の行...
# ...                                                 ...
# 1087                                 ミュラー長官はマーレ兵を率いている。
# 1088                              ミュラー長官とレオンハートは対立している。
# 1089                         ミュラー長官の判断により、停戦状態が維持されている。
# 1090                   ミュラー長官はマーレ人たちの一員であり、彼らと共に行動している。
# 1091                          地ならしは一度停止したが、光る生物は無傷であった。
#
#                                           text_unit_ids  \
# 0     [9258dc9cfa68e628ebcfeb3c266afc0a, d41fb4a2d95...
# 1     [421d996d3592e0c1c8407169f3d37671, d41fb4a2d95...
# 2     [130f4d1eb68e1983573110f8ec9aadc0, d41fb4a2d95...
# 3     [169b95f5ce24ae5e41542fc09d77cdc0, d41fb4a2d95...
# 4     [00e9b2836fe147b23a9993036c9b6d9e, bafd08ad15d...
# ...                                                 ...
# 1087                 [293065765c291721e1665c67e0721f5a]
# 1088                 [293065765c291721e1665c67e0721f5a]
# 1089                 [293065765c291721e1665c67e0721f5a]
# 1090                 [b175d83d3c17db0b44d014aabde68df5]
# 1091                 [0b20d238b2adb6b5822469cacbf8759b]
#
#                                     id human_readable_id  source_degree  \
# 0     e744c118ae7f4638a01d060bbaedd6e9                 0             50
# 1     e1c1080c717d437996def1a41772d179                 1             50
# 2     63fba9a7c47a4f14ac0bee6bc90d0fea                 2             50
# 3     6bfc2395b4f54a528a1ebac94a43acb8                 3             50
# 4     1cce5cebf437428eb1a60dffbdfa603f                 4             50
# ...                                ...               ...            ...
# 1087  5f8224530d424618acb32b74a3afe2c9              1087              6
# 1088  99d4510732d843299514461aebd5f176              1088              6
# 1089  1730cbfab07747508d5b5ea421b97953              1089              6
# 1090  7dd3aadc8f424988a72f8ba3ccf17155              1090              6
# 1091  a2e7cbaf38c24564b2abe61680cacd72              1091              1
#
#       target_degree  rank
# 0                24    74
# 1                18    68
# 2                 4    54
# 3                 6    56
# 4                21    71
# ...             ...   ...
# 1087              2     8
# 1088              3     9
# 1089              1     7
# 1090              3     9
# 1091              4     5
#
# [1092 rows x 10 columns]

# %%
# Out:
#                                    id  \
# 0    d41fb4a2d95c965c1817b27ea3bc40b6
# 1    c22266aa7a3b8dad5964f2058a7cfa76
# 2    4f347bcb9d310113c94275eab0c18d38
# 3    a15e4f02c9644e585c20b4c7baa93482
# 4    8af42708c387a68d5229c8ec6c21bb78
# ..                                ...
# 330  510e15acd6c0fc2368cb078aae377502
# 331  ac2a3d7500b90006daf50cb60df3337c
# 332  f23be42976289c725d3095647118a694
# 333  3d63af807ca12e2f0e0f52cade0fb179
# 334  1a7d14678688cd45c0456bc12fe2ce17
#
#                                                   text  n_tokens  \
# 0    あらすじ\n\n人類は突如出現した「巨人」により滅亡の淵に立たされた。生き残った人類は「ウォ...       100
# 1    大な三重の城壁（甕城）の内側に生活圏を確保することで100年の間、辛うじてその命脈を保ってい...       100
# 2    突出したシガンシナ区で生活する少年エレン・イェーガーは、医者の父グリシャと母カルラ、そしてイ...       100
# 3    �に暮らしていた。壁の外の世界に憧れるエレンは、壁外調査へ出られる調査兵団への入団を希望して...       100
# 4    を出すことから、カルラやミカサには入団を反対されるが、それでもエレンは幼馴染のアルミン・アル...       100
# ..                                                 ...       ...
# 330  �態としては大量の失業者や難民を意図的に減らす「口減らし」や「棄民」の意味合いもあった。\n...       100
# 331  査兵が人語を話す巨人と遭遇したが、帰還叶わず死亡。\n849年\nイルゼ・ラングナーに遺され...       100
# 332  レンの憲兵団引き渡しは凍結される。\n調査と交戦の結果、調査兵団は「女型の巨人」の正体をウォ...       100
# 333  �兵団と憲兵団がウォール・ローゼに到着。ハンジの推測により巨大樹の森を目指し、エレン達の奪還...       100
# 334                                          ちが説得を試みる。        11
#
#                            document_ids  \
# 0    [e310f8b6ea2ed9037e1b4c2afb11df35]
# 1    [e310f8b6ea2ed9037e1b4c2afb11df35]
# 2    [e310f8b6ea2ed9037e1b4c2afb11df35]
# 3    [e310f8b6ea2ed9037e1b4c2afb11df35]
# 4    [e310f8b6ea2ed9037e1b4c2afb11df35]
# ..                                  ...
# 330  [e310f8b6ea2ed9037e1b4c2afb11df35]
# 331  [e310f8b6ea2ed9037e1b4c2afb11df35]
# 332  [e310f8b6ea2ed9037e1b4c2afb11df35]
# 333  [e310f8b6ea2ed9037e1b4c2afb11df35]
# 334  [e310f8b6ea2ed9037e1b4c2afb11df35]
#
#                                             entity_ids  \
# 0    [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1    [4119fd06010c494caa07f439b333f4c5, 19a7f254a5d...
# 2    [19a7f254a5d64566ab5cc15472df02de, 27f9fbe6ad8...
# 3    [e7ffaee9d31d4d3c96e04f911d0a8f9e, de988724cfd...
# 4    [e7ffaee9d31d4d3c96e04f911d0a8f9e, de988724cfd...
# ..                                                 ...
# 330                                               None
# 331                                               None
# 332                                               None
# 333                                               None
# 334                                               None
#
#                                       relationship_ids
# 0    [e744c118ae7f4638a01d060bbaedd6e9, e1c1080c717...
# 1    [268446fc52a54fd2837f73aeb3e0b74f, f6ddfa8491f...
# 2    [1fa6d3118bd846c8837b5fa9fb78f262, 62c65bbae33...
# 3    [3f9a2a2c1c0a424e8b4980ea9d48bdbe, aa2ec452728...
# 4    [aa2ec452728a4703ae1bdabe85b6c079, c5ddb31e0a9...
# ..                                                 ...
# 330                                               None
# 331                                               None
# 332                                               None
# 333                                               None
# 334                                               None
#
# [335 rows x 6 columns]

# %%
# !poetry run python -m graphrag.query --root ./ragtest --data output/20240916-111521/artifacts --method local "エレンとアルミンの関係性は？"
# Out:
# INFO: Vector Store Args: {}
# [2024-09-16T02:52:42Z WARN  lance::dataset] No existing dataset at /Users/morisadakeisuke/Documents/12ml/blogs/simple-graphrag/ragtest/output/20240916-111521/artifacts/lancedb/entity_description_embeddings.lance, it will be created
# creating llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': '2023-07-01-preview', 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# Warning: No community records added when building community context.
#
# SUCCESS: Local Search Response:
# ## エレンとアルミンの関係性
#
# エレン・イェーガーとアルミン・アルレルトは、物語の中で非常に重要な関係を持つキャラクターです。彼らは幼馴染であり、共に第104期訓練兵団に所属していました。二人は壁外への夢を語り合い、互いに支え合う存在として描かれています。エレンはアルミンにとっての強い影響力を持ち、アルミンもまたエレンの行動に大きな影響を与えています [Data: Relationships (120, 206, 250); Entities (6, 21, 254)]。
#
# ### 友情と信頼
#
# エレンとアルミンの友情は、彼らの成長と冒険を通じて深まっていきます。アルミンは非力ではありますが、作戦立案の能力に秀でており、エレンの行動を支える重要な役割を果たしています。特に、アルミンはエレンの意識を取り戻すために呼びかけたり、彼をかばったりするなど、強い絆を持っています [Data: Entities (21, 254); Relationships (250, 390)]。
#
# ### 戦闘における協力
#
# 彼らは共に巨人と戦う中で、互いの能力を活かし合っています。アルミンは「超大型巨人」の能力を受け継ぎ、エレンと共に戦闘に参加することで、彼らの絆はさらに強固なものとなります。また、アルミンはエレンの力を利用して戦略を立てることもあり、彼の知恵が戦闘において重要な役割を果たしています [Data: Entities (453); Sources (275, 291)]。
#
# ### 結論
#
# エレンとアルミンの関係性は、友情、信頼、そして協力に基づいており、物語の中で彼らの成長と冒険を支える重要な要素となっています。彼らの絆は、困難な状況においても互いを支え合う力となり、物語全体における感情的な深みを与えています。

# %%
# !poetry run python -m graphrag.query --root ./ragtest --method local "エレンと幼馴染の人物はどんな特徴がありますか？"
# Out:
# INFO: Vector Store Args: {}
# creating llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': '2023-07-01-preview', 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# Warning: No community records added when building community context.
#
# SUCCESS: Local Search Response:
# エレン・イェーガーの幼馴染には、アルミン・アルレルトとミカサ・アッカーマンがいます。それぞれの特徴について詳しく見ていきましょう。
#
# ### アルミン・アルレルト
# アルミンは、知恵と戦略に優れたキャラクターであり、エレンとミカサの友人です。彼は第104期訓練兵団の一員として、エレンと共に壁外への夢を語り合った幼馴染です。アルミンは特にエレンを導く重要な役割を担っており、彼の知恵を駆使して仲間を助ける姿勢が彼のキャラクターの重要な要素となっています。彼は非力ではありますが、作戦立案の能力に秀でており、仲間たちとの関係を深めていく中で成長を遂げています [Data: Entities (16, 254); Relationships (120, 250)]。
#
# ### ミカサ・アッカーマン
# ミカサは、エレンの親友であり、彼を守るために戦う姿勢を持っています。彼女もまた第104期訓練兵団の一員であり、エレンとアルミンの幼馴染です。ミカサは優れた身体能力を持ち、巨人討伐において傑出した才能があります。彼女の強い絆と戦う意志は、物語の重要な要素となっており、エレンに対する深い思いが彼女の行動に影響を与えています [Data: Entities (12, 253); Relationships (205, 277)]。
#
# ### まとめ
# エレンの幼馴染であるアルミンとミカサは、それぞれ異なる特徴を持ちながらも、共に巨人討伐に挑む仲間として重要な役割を果たしています。アルミンは知恵と戦略に優れ、ミカサは身体能力に秀でたキャラクターであり、彼らの絆は物語の中で大きな意味を持っています。

# %%
# !poetry run python -m graphrag.query --root ./ragtest --method local "エレンとアルミンの関係性は？"
# Out:
# INFO: Vector Store Args: {}
# creating llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': '2023-07-01-preview', 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# Warning: No community records added when building community context.
#
# SUCCESS: Local Search Response:
# ## エレンとアルミンの関係性
#
# エレン・イェーガーとアルミン・アルレルトは、物語の中で非常に重要な関係を持つキャラクターです。彼らは幼馴染であり、共に第104期訓練兵団に所属していました。二人は壁外への夢を語り合い、互いに支え合う存在として描かれています。エレンはアルミンにとっての強い影響力を持ち、アルミンもまたエレンの行動に大きな影響を与えています [Data: Relationships (120, 206, 250); Entities (6, 21)]。
#
# ### 友情と信頼
#
# エレンとアルミンの友情は、彼らの成長と冒険の中で深まっていきます。アルミンは非力ではありますが、作戦立案の能力に秀でており、エレンの行動を支える重要な役割を果たしています。特に、アルミンはエレンの意識を取り戻すために呼びかけたり、彼をかばったりするなど、強い絆を持っています [Data: Entities (21, 254); Relationships (250, 390)]。
#
# ### 危機的状況での連携
#
# 物語の中で、エレンとアルミンは数々の危機的状況に直面しますが、常に互いに助け合いながら行動しています。アルミンは、エレンの巨人化能力を利用して作戦を立てたり、仲間たちを安全地帯へ脱出させるために力を合わせたりしています。このように、彼らの関係は単なる友情を超え、戦略的なパートナーシップとしても機能しています [Data: Entities (453); Sources (275, 291)]。
#
# ### 結論
#
# エレンとアルミンの関係性は、物語の進行において非常に重要な要素です。彼らの友情、信頼、そして互いに支え合う姿勢は、物語のテーマやキャラクターの成長に大きな影響を与えています。彼らの絆は、困難な状況においても揺るがないものであり、物語の中での彼らの役割を際立たせています [Data: Sources (7, 10, 12)].

# %%
# !poetry run python -m graphrag.query --root ./ragtest --data output/20240916-111521/artifacts --method global "この物語の中で，彼らはどんなことを成し遂げましたか？"
# Out:
# creating llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': '2023-07-01-preview', 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Global Search Response:
# ## 物語の中での成し遂げたこと
#
# この物語において、主要なキャラクターたちはそれぞれの役割を果たし、様々な成果を上げています。以下に、彼らの成し遂げたことをまとめます。
#
# ### エレン・イェーガーの貢献
#
# エレン・イェーガーは、物語の中心的なキャラクターとして、巨人との戦いにおいて重要な役割を果たしました。彼はパラディ島のリーダーとして、島の防衛と攻撃の両面で活躍し、特に超大型巨人と共にマーレに侵攻したことが物語の進行に大きな影響を与えました [Data: Reports (78, 102)]。また、彼の巨人化能力は仲間たちを鼓舞し、戦局において決定的な役割を果たしました [Data: Reports (74)]。
#
# ### 調査兵団の活動
#
# 調査兵団は、巨人に対抗するための戦闘を行い、特にエルヴィン団長の指導の下でのシガンシナ区の奪回作戦や女型の巨人の捕獲作戦は、彼らの活動の中でも特に重要な位置を占めています [Data: Reports (94)]。彼らの戦略や士気は、物語のテーマである犠牲や勇気を強調する要素となりました [Data: Reports (77)]。
#
# ### ジークの影響
#
# ジークは「獣の巨人」としての力を持ち、彼の「叫び」によって巨人が発生し、エルディア人戦士隊や調査兵団との関係が複雑に絡み合っています。彼の行動はエルディア国の運命に直接的な影響を与えています [Data: Reports (90)]。
#
# ### ヒストリアのリーダーシップ
#
# ヒストリアは新政権を樹立し、社会的な問題に取り組む姿勢を見せることで、彼女のリーダーシップが物語において重要な変化をもたらしました。彼女は孤児院を開設し、人々から尊敬される存在となりました [Data: Reports (60)]。彼女の決断は他のキャラクターとの関係性に大きな影響を与えています [Data: Reports (44)]。
#
# ### 仲間たちの絆
#
# エレンとミカサの強い絆は、共に戦闘に参加し、互いを救うために協力し合うことで物語の中心的な要素となっています [Data: Reports (84)]。また、104期訓練兵団のメンバーは、エレンの奪還作戦に参加し、彼らの団結と信頼が物語の進行において重要な役割を果たしました [Data: Reports (31)]。
#
# ## 結論
#
# この物語において、キャラクターたちはそれぞれの役割を通じて、巨人との戦い、社会の変革、仲間との絆を深めることに成功しました。彼らの行動は物語の進行に大きな影響を与え、各キャラクターの成長や変化を促す要因となっています。
